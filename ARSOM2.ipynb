# %% [markdown]
# ### Group 1

# %%
import pandas as pd
import numpy as np

import gurobipy as gp
from gurobipy import GRB

#Importing the matrices a,b and c from excel
a=pd.read_csv('a.csv',header=None).values
b=pd.read_csv('b.csv',header=None).values
c=pd.read_csv('c.csv',header=None).values



try:
    m = gp.Model()
    
    #define decision variables
    xtrans = m.addVars(287, vtype=GRB.BINARY, name='xtrans')
    xnon= m.addVars(4, vtype=GRB.BINARY, name='xnon')
    y = m.addVars(61, vtype=GRB.BINARY, name='y')
    z = m.addVars(190, vtype=GRB.BINARY, name='z')

    #set objective functions with quicksum function
    m.setObjective(gp.quicksum(y[j] for j in range(61))+gp.quicksum(z[k] for k in range(190))
                   +gp.quicksum(xnon[i] for i in range(4))
                   -750*gp.quicksum(xtrans[i] for i in range(287)), GRB.MINIMIZE) 

    #Constraints
    m.addConstrs(sum(c[i][k]*z[k] for k in range(190)) >= xtrans[i] for i in range(287))
    m.addConstrs(sum(c[i+137][k]*z[k] for k in range(405)) <= 405*xnon[i] for i in range(214))
    m.addConstrs(sum(b[j][k]*z[k] for k in range(405)) <= 405*y[j] for j in range(29))
    

    m.optimize()

    for v in m.getVars():
        print('%s = %g' % (v.varName, v.x))
        
    print('Obj: %g' % m.objVal)



except gp.GurobiError as e:
    print('Error code ' + str(e.errno) + ': ' + str(e))

except AttributeError:
    print('Encountered an attribute error')
# Out:
# Using license file C:\Users\arush\gurobi.lic
# Academic license - for non-commercial use only
# Gurobi Optimizer version 9.0.1 build v9.0.1rc0 (win64)
# Optimize a model with 380 rows, 785 columns and 15191 nonzeros
# Model fingerprint: 0xfc4e837d
# Variable types: 0 continuous, 785 integer (785 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+02]
#   Objective range  [1e+00, 8e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 117 rows and 235 columns
# Presolve time: 0.09s
# Presolved: 263 rows, 550 columns, 11743 nonzeros
# Found heuristic solution: objective -3747.000000
# Variable types: 0 continuous, 550 integer (550 binary)
#
# Root relaxation: objective -9.896599e+04, 208 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# ...

# %%
m.write("file.lp")

# %%
##Printing all variables with z=1
m.printAttr('x')
# Out:
#     Variable            x
# -------------------------
#    xtrans[0]            1
#    xtrans[1]            1
#    xtrans[2]            1
#    xtrans[3]            1
#    xtrans[4]            1
#    xtrans[5]            1
#    xtrans[6]            1
#    xtrans[7]            1
#    xtrans[8]            1
#    xtrans[9]            1
#   xtrans[10]            1
#   xtrans[11]            1
#   xtrans[12]            1
#   xtrans[13]            1
#   xtrans[14]            1
#   xtrans[15]            1
#   xtrans[16]            1
#   xtrans[17]            1
#   xtrans[18]            1
#   xtrans[19]            1
#   xtrans[20]            1
#   xtrans[22]            1
#   xtrans[23]            1
#   xtrans[24]            1
#   xtrans[26]            1
#   xtrans[27]            1
#   xtrans[28]            1
#   xtrans[29]            1
#   xtrans[30]            1
#   xtrans[31]            1
#   xtrans[32]            1
#   xtrans[33]            1
#   xtrans[34]            1
# ...

# %%
### ARSOM2

# %%
import pandas as pd
import numpy as np

import gurobipy as gp
from gurobipy import GRB

#Importing the matrices a,b and c from excel
a=pd.read_csv('a.csv',header=None).values
b=pd.read_csv('b.csv',header=None).values
c=pd.read_csv('c.csv',header=None).values



try:
    m = gp.Model()
    
    #Decision Variables
    xtrans = m.addVars(295, vtype=GRB.BINARY, name='xtrans')
    xnon= m.addVars(41, vtype=GRB.BINARY, name='xnon')
    y = m.addVars(57, vtype=GRB.BINARY, name='y')
    z = m.addVars(140, vtype=GRB.BINARY, name='z')

    #Objective function
    m.setObjective(gp.quicksum(y[j] for j in range(57))
                   +gp.quicksum(z[k] for k in range(140))
                   +gp.quicksum(xnon[i] for i in range(41))
                   -750*gp.quicksum(xtrans[i] for i in range(295)), GRB.MINIMIZE) 

    #Constraints
    m.addConstrs(sum(c[i][k]*z[k] for k in range(140)) >= xtrans[i] for i in range(295))
    m.addConstrs(sum(c[i+295][k]*z[k] for k in range(140)) <= 140*xnon[i] for i in range(41))
    m.addConstrs(sum(b[j][k]*z[k] for k in range(140)) <= 140*y[j] for j in range(57))
    

    m.optimize()

    for v in m.getVars():
        print('%s = %g' % (v.varName, v.x))
        
    print('Obj: %g' % m.objVal)



except gp.GurobiError as e:
    print('Error code ' + str(e.errno) + ': ' + str(e))

except AttributeError:
    print('Encountered an attribute error')
# Out:
# Gurobi Optimizer version 9.0.1 build v9.0.1rc0 (win64)
# Optimize a model with 269 rows, 392 columns and 2658 nonzeros
# Model fingerprint: 0x677bf84b
# Variable types: 0 continuous, 392 integer (392 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 133 rows and 159 columns
# Presolve time: 0.01s
# Presolved: 136 rows, 233 columns, 2076 nonzeros
# Found heuristic solution: objective -9947.000000
# Variable types: 0 continuous, 233 integer (233 binary)
#
# Root relaxation: objective -5.391134e+04, 93 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -53911.336    0   60 -9947.0000 -53911.336   442%     -    0s
# ...

# %%
m.write("file.lp")

# %%
##Printing all variables with z=1
m.printAttr('x')
# Out:
#     Variable            x
# -------------------------
#    xtrans[0]            1
#    xtrans[3]            1
#    xtrans[4]            1
#    xtrans[5]            1
#    xtrans[6]            1
#    xtrans[7]            1
#    xtrans[8]            1
#    xtrans[9]            1
#   xtrans[10]            1
#   xtrans[11]            1
#   xtrans[12]            1
#   xtrans[13]            1
#   xtrans[14]            1
#   xtrans[15]            1
#   xtrans[16]            1
#   xtrans[17]            1
#   xtrans[18]            1
#   xtrans[19]            1
#   xtrans[20]            1
#   xtrans[21]            1
#   xtrans[22]            1
#   xtrans[23]            1
#   xtrans[24]            1
#   xtrans[26]            1
#   xtrans[27]            1
#   xtrans[28]            1
#   xtrans[29]            1
#   xtrans[30]            1
#   xtrans[31]            1
#   xtrans[32]            1
#   xtrans[33]            1
#   xtrans[34]            1
#   xtrans[35]            1
# ...

# %%
 ### Group 3

# %%
import pandas as pd
import numpy as np

import gurobipy as gp
from gurobipy import GRB

#Importing the matrices a,b and c from excel
a=pd.read_csv('a3.csv',header=None).values
b=pd.read_csv('b3.csv',header=None).values
c=pd.read_csv('c3.csv',header=None).values



try:
    m = gp.Model()
    
    #Decision Variables
    xtrans = m.addVars(63, vtype=GRB.BINARY, name='xtrans')
    xnon= m.addVars(82, vtype=GRB.BINARY, name='xnon')
    y = m.addVars(29, vtype=GRB.BINARY, name='y')
    z = m.addVars(204, vtype=GRB.BINARY, name='z')

    #Objective function
    m.setObjective(gp.quicksum(y[j] for j in range(29))
                   +gp.quicksum(z[k] for k in range(204))
                   +gp.quicksum(xnon[i] for i in range(82))
                   -750*gp.quicksum(xtrans[i] for i in range(63)), GRB.MINIMIZE) 

    #Constraints
    m.addConstrs(sum(c[i][k]*z[k] for k in range(204)) >= xtrans[i] for i in range(63))
    m.addConstrs(sum(c[i+63][k]*z[k] for k in range(204)) <= 123*xnon[i] for i in range(82))
    m.addConstrs(sum(b[j][k]*z[k] for k in range(204)) <= 123*y[j] for j in range(29))
    

    m.optimize()

    for v in m.getVars():
        print('%s = %g' % (v.varName, v.x))
        
    print('Obj: %g' % m.objVal)



except gp.GurobiError as e:
    print('Error code ' + str(e.errno) + ': ' + str(e))

except AttributeError:
    print('Encountered an attribute error')
# Out:
# Gurobi Optimizer version 9.0.1 build v9.0.1rc0 (win64)
# Optimize a model with 174 rows, 378 columns and 3903 nonzeros
# Model fingerprint: 0xe792dc62
# Variable types: 0 continuous, 378 integer (378 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+00, 8e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 42 rows and 106 columns
# Presolve time: 0.02s
# Presolved: 132 rows, 272 columns, 2802 nonzeros
# Found heuristic solution: objective -2976.000000
# Variable types: 0 continuous, 272 integer (272 binary)
#
# Root relaxation: objective -4.422865e+04, 103 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -44228.651    0   66 -2976.0000 -44228.651  1386%     -    0s
# ...

# %%
m.write("file.lp")

# %%
##Printing all variables with z=1
m.printAttr('x')
# Out:
#     Variable            x
# -------------------------
#    xtrans[0]            1
#    xtrans[2]            1
#    xtrans[3]            1
#    xtrans[4]            1
#    xtrans[5]            1
#    xtrans[6]            1
#    xtrans[7]            1
#    xtrans[8]            1
#   xtrans[10]            1
#   xtrans[11]            1
#   xtrans[12]            1
#   xtrans[13]            1
#   xtrans[14]            1
#   xtrans[15]            1
#   xtrans[16]            1
#   xtrans[17]            1
#   xtrans[18]            1
#   xtrans[19]            1
#   xtrans[20]            1
#   xtrans[21]            1
#   xtrans[22]            1
#   xtrans[23]            1
#   xtrans[24]            1
#   xtrans[25]            1
#   xtrans[26]            1
#   xtrans[27]            1
#   xtrans[28]            1
#   xtrans[30]            1
#   xtrans[31]            1
#   xtrans[32]            1
#   xtrans[33]            1
#   xtrans[34]            1
#   xtrans[35]            1
# ...

# %%
### Group 4

# %%
import pandas as pd
import numpy as np

import gurobipy as gp
from gurobipy import GRB

#Importing the matrices a,b and c from excel
a=pd.read_csv('a4.csv',header=None).values
b=pd.read_csv('b4.csv',header=None).values
c=pd.read_csv('c4.csv',header=None).values



try:
    m = gp.Model()
    
    #define decision variables
    xtrans = m.addVars(48, vtype=GRB.BINARY, name='xtrans')
    xnon= m.addVars(260, vtype=GRB.BINARY, name='xnon')
    y = m.addVars(29, vtype=GRB.BINARY, name='y')
    z = m.addVars(13, vtype=GRB.BINARY, name='z')

    #set objective functions with quicksum function
    m.setObjective(gp.quicksum(y[j] for j in range(29))+gp.quicksum(z[k] for k in range(13))
                   +gp.quicksum(xnon[i] for i in range(260))
                   -750*gp.quicksum(xtrans[i] for i in range(48)), GRB.MINIMIZE) 

    #Constraints
    m.addConstrs(sum(c[i][k]*z[k] for k in range(13)) >= xtrans[i] for i in range(48))
    m.addConstrs(sum(c[i+48][k]*z[k] for k in range(13)) <= 13*xnon[i] for i in range(260))
    m.addConstrs(sum(b[j][k]*z[k] for k in range(13)) <= 13*y[j] for j in range(29))
    

    m.optimize()

    for v in m.getVars():
        print('%s = %g' % (v.varName, v.x))
        
    print('Obj: %g' % m.objVal)



except gp.GurobiError as e:
    print('Error code ' + str(e.errno) + ': ' + str(e))

except AttributeError:
    print('Encountered an attribute error')
# Out:
# Gurobi Optimizer version 9.0.1 build v9.0.1rc0 (win64)
# Optimize a model with 337 rows, 350 columns and 536 nonzeros
# Model fingerprint: 0x98b967ce
# Variable types: 0 continuous, 350 integer (350 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 8e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 0.0000000
# Presolve removed 315 rows and 318 columns
# Presolve time: 0.00s
# Presolved: 22 rows, 32 columns, 95 nonzeros
# Found heuristic solution: objective -9724.000000
# Variable types: 0 continuous, 32 integer (32 binary)
#
# Root relaxation: objective -2.396818e+04, 7 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -23968.183    0    9 -9724.0000 -23968.183   146%     -    0s
# ...

# %%
m.write("file.lp")

# %%
##Printing all variables with z=1
m.printAttr('x')
# Out:
#     Variable            x
# -------------------------
#    xtrans[3]            1
#    xtrans[6]            1
#    xtrans[7]            1
#    xtrans[9]            1
#   xtrans[10]            1
#   xtrans[12]            1
#   xtrans[13]            1
#   xtrans[14]            1
#   xtrans[15]            1
#   xtrans[16]            1
#   xtrans[17]            1
#   xtrans[19]            1
#   xtrans[20]            1
#   xtrans[22]            1
#   xtrans[24]            1
#   xtrans[25]            1
#   xtrans[26]            1
#   xtrans[27]            1
#   xtrans[28]            1
#   xtrans[29]            1
#   xtrans[30]            1
#   xtrans[32]            1
#   xtrans[34]            1
#   xtrans[35]            1
#   xtrans[36]            1
#   xtrans[37]            1
#   xtrans[38]            1
#   xtrans[40]            1
#   xtrans[41]            1
#   xtrans[42]            1
#   xtrans[43]            1
#   xtrans[47]            1
#      xnon[0]            1
# ...
